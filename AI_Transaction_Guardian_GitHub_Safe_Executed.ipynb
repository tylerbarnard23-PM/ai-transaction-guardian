# %% [markdown]
# # AI Transaction Guardian – GitHub-Safe Executed Notebook

# %%
print('Notebook loaded successfully')
# Out:
# Notebook loaded successfully

# %%
import pandas as pd
import numpy as np
print('Imports OK')
# Out:
# Imports OK

# %%
df = pd.DataFrame({'amount':[10,20,30],'is_fraud':[0,1,0]})
df

# %%
print('Rows:', len(df))
# Out:
# Rows: 3
